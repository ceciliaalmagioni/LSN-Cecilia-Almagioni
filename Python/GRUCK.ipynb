# %% [markdown]
# Esercizio 7

# %%
import matplotlib.pyplot as plt
import numpy as np

#cosa cambia tra u e stima u??
#energia interna metropolis??

x, y, errK = np.loadtxt("/home/cecilia/Scrivania/LabSN/Esercitazioni/Es7/MDNVE_MCNVT/output_ekin.dat",unpack=True,usecols=(0, 1, 3))

plt.errorbar(x, ekin, yerr=errK)
plt.xlabel('#throws')
plt.ylabel('')
plt.grid(True)
#plt.title('Valore medio')
plt.show()
