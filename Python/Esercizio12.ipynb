# %% [markdown]
# *Laboratorio di Simulazione Numerica- Cecilia Almagioni*
#
# # Esercitazione 12
#
# In questa esercitazione, mi sono dedicata all'utilizzo di modelli di deep neural network implementati con il pacchetto Keras in Python. L' obiettivo è quello di distinguere e riconoscere cifre scritte a mano da 0 a 9. Per allenare la rete neurale, è stato sfruttato il dataset MNIST, costituito da immagini di cifre scritte a mano, rappresentate in una griglia di pixel di dimensione $28$x$28$.
#
# Il problema che voglio affrontare si inserisce nella categoria generale della classificazione. Il mio intento è infatti quello di addestrare i modelli per assegnare correttamente le immagini delle cifre alle rispettive classi da 0 a 9, ovvero etichettarle in modo appropriato.

# %% [markdown]
# ### Exercise 12.1
#
#
# In questo esercizio utilizzo il codice fornito a lezione per imparare il funzionamento delle DDN modificando il numero di epoche e l'ottimizzatore. Cercherò inoltre di migliorare le performance della rete. Per valutare le performance utilizzo accuratezza e loss restituite dal codice.

# %% [markdown]
# Il codice fornito usa 5 epoche e lo Stocastic Gradient Descent `sgd` come ottimizzatore. (Test loss: 0.16558237373828888 e Test accuracy: 0.949999988079071)

# %%
from PIL import Image
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# Carica l'immagine
image = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/SGD_5.png')  
image2 = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/SGD_5_digits.png')

# Mostra l'immagine
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Rimuovi gli assi
plt.show()
plt.figure(figsize=(10, 10))
plt.imshow(image2)
plt.axis('off')  # Rimuovi gli assi
display(HTML("<style>.input{display: none !important;}</style>"))
plt.show()
# Out:
# <style>.input{display: none !important;}</style>

# %% [markdown]
# Mantenendo lo `sgd` come ottimizzatore, aumento il numero di epoche a 10. Migliorano loss e accuracy del training e il 5 che a 5 epoche veniva interpretato come 6, adesso risulta interpretato correttamente. (Test loss: 0.10931472480297089 e Test accuracy: 0.9663000106811523)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Carica l'immagine
image = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/SGD_10.png')  
image2 = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/SGD_10_digits.png')

# Mostra l'immagine
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Rimuovi gli assi
plt.show()
plt.figure(figsize=(10, 10))
plt.imshow(image2)
plt.axis('off')  # Rimuovi gli assi
plt.show()

# %% [markdown]
# Mantenendo 10 epoche, ho cambiato ottimizzatore scegliendo `Adadelta`. Di nuovo il 5 viene letto male e  loss e accurcy training non convergono. (Test loss: 0.9460806846618652 e Test accuracy: 0.8341000080108643)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Carica l'immagine
image = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/Add_10.png')  
image2 = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/Add_10_digits.png')

# Mostra l'immagine
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Rimuovi gli assi
plt.show()
plt.figure(figsize=(10, 10))
plt.imshow(image2)
plt.axis('off')  # Rimuovi gli assi
plt.show()

# %% [markdown]
# Per questo motivo, provo ad aumentare il numero di epoche a 20. (Test loss: 0.5913074016571045 e Test accuracy: 0.8784999847412109)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Carica l'immagine
image = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/Add_20.png')  
image2 = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/Add_20_digits.png')

# Mostra l'immagine
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Rimuovi gli assi
plt.show()
plt.figure(figsize=(10, 10))
plt.imshow(image2)
plt.axis('off')  # Rimuovi gli assi
plt.show()

# %% [markdown]
# La migliore combinazione tra quelle provate sembrerebbe `Adam` che con solo 10 epoche ha dei buoni valori per loss e accuracy e predice tutte le cifre correttamente. (Test loss: 0.09633710235357285 e Test accuracy: 0.9807999730110168)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Carica l'immagine
image = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/ADAM_10.png')  
image2 = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/ADAM_10_digits.png')

# Mostra l'immagine
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Rimuovi gli assi
plt.show()
plt.figure(figsize=(10, 10))
plt.imshow(image2)
plt.axis('off')  # Rimuovi gli assi
plt.show()

# %% [markdown]
# ### Esercizio 12.2
#
# A questo punto, cambio l'architettura della rete neurale da DNN (rete neurale profonda) a CNN (rete neurale convoluzionale). Una rete convoluzionale è in grado di sfruttare le correlazioni spaziali locali che esistono tra i pixel per migliorare le performance. Per farlo, è necessario riformattare i dati.
#
#
#
# Spiegare meglio ???

# %% [markdown]
# Per il confronto con la DNN abbiamo scelto come ottimizzatore `Adam` con 10 epoche, ottenendo Test loss: 0.030765613541007042 e Test accuracy: 0.9902999997138977. Le performance sono dunque migliorate con la CNN.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Carica l'immagine
image = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/CNN_ADAM.png')  
image2 = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/CNN_ADAM_digits.png')

# Mostra l'immagine
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Rimuovi gli assi
plt.show()
plt.figure(figsize=(10, 10))
plt.imshow(image2)
plt.axis('off')  # Rimuovi gli assi
plt.show()

# %% [markdown]
# ### Esercizio 12.3
#
# Utilizzando l'applicazione `gimp` ho creato 10 immagini delle cifre scritte da me e ho chiesto alla mia rete neurale convoluzionale di riconoscerle. Dato che ho ottenuto una buona performance nell'esercizio precedente, ho mantenuto come ottimizzatore `Adam` con 10 epoche. Le cifre sono state riconosciute con successo.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Carica l'immagine
image = Image.open('/home/cecilia/Scrivania/LabSN/Esercitazioni/Python/my_digits.png') 
larger_image = image.resize((image.width * 15, image.height * 15))

# Mostra l'immagine
plt.figure(figsize=(10, 10))
plt.imshow(larger_image)
plt.axis('off')  # Rimuovi gli assi
plt.show()
plt.axis('off')  # Rimuovi gli assi
plt.show()
